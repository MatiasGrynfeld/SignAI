# %%
from KeyFrameExtractorClass import KeyFrameExtractor
from Points2VecClass import Point2Vec
import cv2
from VideoFormaterClass import VideoFormater

# %%
videoRute1 = "C:\\Users\\48519558\\Desktop\\SignAI-ML\\AI-ML_Development\\recursos\\videoprueba1.mp4"
videoRute2 = "C:\\Users\\48519558\\Desktop\\SignAI-ML\\AI-ML_Development\\recursos\\videoprueba2.mp4"
videoRute3 = "C:\\Users\\48519558\\Desktop\\SignAI-ML\\AI-ML_Development\\recursos\\videoprueba3.mp4"
videoRute4 = "C:\\Users\\48519558\\Desktop\\SignAI-ML\\AI-ML_Development\\recursos\\videoprueba4.mp4"
video1 = cv2.VideoCapture(videoRute1)
video2 = cv2.VideoCapture(videoRute2)
#video3 = cv2.VideoCapture(videoRute3)
#video4 = cv2.VideoCapture(videoRute4)
videos = [video1, video2]#, video3, video4]
KFE = KeyFrameExtractor()

poseKeyFrames = [KFE.extractKeyFrames(return_frame=False, draw=False, video=video) for video in videos]
# Out:
# C:\Users\48519558\AppData\Roaming\Python\Python310\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
dfs = []
videoFormater = VideoFormater()
normalizer = Point2Vec(4)
for index, poseKeyFrame in enumerate(poseKeyFrames):
    landmarks = normalizer.land2vec(poseKeyFrame)
    dfs.append(VideoFormater.formatVideo(VideoFormater, landmarks, index))

VideoFormater.concatAndExportVideos(videoFormater, dfs)
