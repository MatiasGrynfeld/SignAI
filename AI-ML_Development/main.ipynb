# %%
from KeyFrameExtractorClass import KeyFrameExtractor
from Points2VecClass import Point2Vec
import cv2

# %%
videoRute = "C:\\Users\\48519558\\Desktop\\SignAI-ML\\AI-ML_Development\\recursos\\videoprueba4.mp4"
video = cv2.VideoCapture(videoRute)

KFE = KeyFrameExtractor()

poseKeyFrames = KFE.extractKeyFrames(return_frame=False, draw=False, video=video)
print(len(poseKeyFrames))
# Out:
# C:\Users\48519558\AppData\Roaming\Python\Python310\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 4.759591114348682
# 125

# %%
if poseKeyFrames:
    normalizer = Point2Vec(4)
    #landmarks = normalizer.land2vec(poseKeyFrames)
    landmarks = normalizer.CNNMaxtrix(poseKeyFrames)
    print(landmarks)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 normalizer = Point2Vec(4)
#       3 #landmarks = normalizer.land2vec(poseKeyFrames)
# ----> 4 landmarks = normalizer.CNNMaxtrix(poseKeyFrames)
#       5 print(landmarks)
#
# File c:\Users\48519558\Desktop\SignAI-ML\AI-ML_Development\Points2VecClass.py:55, in Point2Vec.CNNMaxtrix(self, landmarks)
#      54 def CNNMaxtrix(self, landmarks):
# ---> 55     vector = self.land2vec(landmarks).flatten()
#      56     returnVector = []
#      57     for keyFrame in vector:
#
# AttributeError: 'list' object has no attribute 'flatten'
