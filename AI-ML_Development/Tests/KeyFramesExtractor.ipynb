# %%
import cv2
import mediapipe as mp
import os

# %%
def initialize_mediapipe():
    mp_hands = mp.solutions.hands
    mp_drawing = mp.solutions.drawing_utils
    hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5, min_tracking_confidence=0.5)
    return mp_hands, mp_drawing, hands

def procesar_frame(frame, hands):
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = hands.process(image)
    return results

def calcular_diferencia(puntos_previos,puntos_actuales, handedness_prev, handedness_actual):
    if puntos_previos is None or puntos_actuales is None:
        return 10.0
    
    # Comprobamos si alguna de las listas está vacía o si las dos listas tienen diferentes longitudes
    if len(puntos_previos) != len(puntos_actuales):
        return 10.0

    num_hands_previas = len(puntos_previos)
    num_hands_actuales = len(puntos_actuales)

    if num_hands_previas != num_hands_actuales:
        return 10.0

    total_diff = 0.0
    if len(puntos_previos) == len(puntos_actuales) and len(puntos_actuales) == 2:
        if handedness_prev[0].classification[0].label != handedness_actual[0].classification[0].label:
            puntos_actuales = puntos_actuales[::-1]
    for i in range(num_hands_previas):
        hand_prev = puntos_previos[i].landmark
        hand_actual = puntos_actuales[i].landmark

        diff = sum([
            abs(lm1.x - lm2.x) + abs(lm1.y - lm2.y) + abs(lm1.z - lm2.z)
            for lm1, lm2 in zip(hand_prev, hand_actual)
        ])
        total_diff += diff
    print("Total dif", total_diff)
    if num_hands_previas >= 2:
        print(total_diff)
        total_diff /= num_hands_previas
    print(total_diff)
    return float(total_diff)

def extract_key_frames(video, threshold=4.4, min_frame_interval=3):
    mp_hands, mp_drawing, hands = initialize_mediapipe()
    puntos_previos = []
    handedness_prev = []
    key_frames = []
    frame_count = 0
    print("Iniciando la extracción de frames clave")

    while video.isOpened():
        ret, frame = video.read()
        if not ret:
            print("Fin del video o error al leer frame")
            break
        
        frame_count += 1
        if len(key_frames)==0 or frame_count - key_frames[-1][1] > min_frame_interval:
            results = procesar_frame(frame, hands)
            
            if results.multi_hand_landmarks:
                puntos_actuales = results.multi_hand_landmarks
                handedness_actual = results.multi_handedness if results.multi_handedness else []
                diff = calcular_diferencia(puntos_previos, puntos_actuales, handedness_prev, handedness_actual)

                if diff > threshold:
                    key_frames.append((frame, frame_count))
                    puntos_previos = puntos_actuales
                    handedness_prev = handedness_actual
            else:
                puntos_previos = None

    video.release()
    return [frame for frame, _ in key_frames]

def save_key_frames(key_frames, output_folder):
    for idx, key_frame in enumerate(key_frames):
        cv2.imwrite(f'{output_folder}/key_frame_{idx}.png', key_frame)

# %%
video_path = 'C:\\Users\\48113164\\Documents\\GitHub\\SignAI-IA.dev\\recursos\\videoprueba1.mp4'
output_folder='C:\\Users\\48113164\\Documents\\GitHub\\SignAI-IA.dev\\recursos\\frames'
video = cv2.VideoCapture(video_path)
if not os.path.isfile(video_path):
    print(f"Error: El archivo {video_path} no existe.")
elif not video.isOpened():
    print("Error: No se pudo abrir el video.")
else:
    key_frames = extract_key_frames(video)
    save_key_frames(key_frames, output_folder)
# Out:
# Iniciando la extracción de frames clave
# c:\Users\48113164\Documents\GitHub\SignAI-IA.dev\.venv\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# [classification {
#   index: 0
#   score: 0.986866474
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.956997693
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.933222175
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.926699281
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 9.071300936933923
# 9.071300936933923
# 4.535650468466962
# [classification {
#   index: 0
#   score: 0.982199
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.957530737
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.426340549177439
# 4.426340549177439
# 2.2131702745887196
# [classification {
#   index: 0
#   score: 0.978651464
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.964410841
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 6.226693035749747
# 6.226693035749747
# 3.1133465178748736
# [classification {
#   index: 0
#   score: 0.984384537
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.95901674
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 6.172700031457765
# 6.172700031457765
# 3.0863500157288826
# [classification {
#   index: 0
#   score: 0.985304475
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.963754833
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 6.213358401165593
# 6.213358401165593
# 3.1066792005827963
# [classification {
#   index: 0
#   score: 0.982976258
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.968726516
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 6.1599725500338
# 6.1599725500338
# 3.0799862750169
# [classification {
#   index: 0
#   score: 0.98086983
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.969724774
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.862859277756499
# 5.862859277756499
# 2.9314296388782495
# [classification {
#   index: 0
#   score: 0.983517
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.970395327
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.571480675527525
# 5.571480675527525
# 2.7857403377637624
# [classification {
#   index: 0
#   score: 0.976797044
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.963857591
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.396009807638492
# 5.396009807638492
# 2.698004903819246
# [classification {
#   index: 0
#   score: 0.983755589
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.966106832
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 6.260362149818363
# 6.260362149818363
# 3.1301810749091814
# [classification {
#   index: 0
#   score: 0.992179573
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.967921078
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 7.834775848763002
# 7.834775848763002
# 3.917387924381501
# [classification {
#   index: 0
#   score: 0.995169818
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.968730628
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 9.516618920713412
# 9.516618920713412
# 4.758309460356706
# [classification {
#   index: 1
#   score: 0.975847661
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.977223
#   label: "Right"
# }
# ]
# num manos previas 1
# Total dif 0.3338519658049677
# 0.3338519658049677
# [classification {
#   index: 1
#   score: 0.970895886
#   label: "Right"
# }
# ]
# num manos previas 1
# Total dif 0.3771020378856207
# 0.3771020378856207
# [classification {
#   index: 1
#   score: 0.97924906
#   label: "Right"
# }
# ]
# num manos previas 1
# Total dif 0.309460479528866
# 0.309460479528866
# [classification {
#   index: 1
#   score: 0.978999674
#   label: "Right"
# }
# ]
# num manos previas 1
# Total dif 0.2834358024772996
# 0.2834358024772996
# [classification {
#   index: 1
#   score: 0.972337186
#   label: "Right"
# }
# ]
# num manos previas 1
# Total dif 0.42285591575504355
# 0.42285591575504355
# [classification {
#   index: 1
#   score: 0.975295842
#   label: "Right"
# }
# ]
# num manos previas 1
# Total dif 0.7550010171074888
# 0.7550010171074888
# [classification {
#   index: 1
#   score: 0.960598946
#   label: "Right"
# }
# ]
# num manos previas 1
# Total dif 1.2879316723214913
# 1.2879316723214913
# [classification {
#   index: 0
#   score: 0.883028865
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.931188703
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.97733283
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.988516808
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.952637553
#   label: "Right"
# }
# ]
# [classification {
#   index: 0
#   score: 0.986413
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.919686317
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.388110228118279
# 4.388110228118279
# 2.1940551140591396
# [classification {
#   index: 0
#   score: 0.985932469
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.902139246
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.665956856387183
# 4.665956856387183
# 2.3329784281935915
# [classification {
#   index: 0
#   score: 0.986236036
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.905194402
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.747432346311129
# 4.747432346311129
# 2.3737161731555645
# [classification {
#   index: 0
#   score: 0.986144543
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.91823864
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.791252929885388
# 4.791252929885388
# 2.395626464942694
# [classification {
#   index: 0
#   score: 0.987682343
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.911607802
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.689693786015042
# 4.689693786015042
# 2.344846893007521
# [classification {
#   index: 0
#   score: 0.986623645
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.922303796
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.523890479336131
# 4.523890479336131
# 2.2619452396680657
# [classification {
#   index: 0
#   score: 0.983386159
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.955902
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.326328459069387
# 4.326328459069387
# 2.1631642295346936
# [classification {
#   index: 0
#   score: 0.98630619
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.969931066
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 3.941535473918279
# 3.941535473918279
# 1.9707677369591394
# [classification {
#   index: 0
#   score: 0.986476481
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.980123818
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 3.6972413987542367
# 3.6972413987542367
# 1.8486206993771184
# [classification {
#   index: 0
#   score: 0.992581844
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.985985339
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 3.625506000614612
# 3.625506000614612
# 1.812753000307306
# [classification {
#   index: 0
#   score: 0.994060755
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.979600191
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.098861758748283
# 4.098861758748283
# 2.0494308793741416
# [classification {
#   index: 0
#   score: 0.99779433
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.985324383
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.853832162442082
# 4.853832162442082
# 2.426916081221041
# [classification {
#   index: 0
#   score: 0.990370214
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.976276159
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.185384474347956
# 5.185384474347956
# 2.592692237173978
# [classification {
#   index: 0
#   score: 0.990308046
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.988482773
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.359095481748763
# 5.359095481748763
# 2.6795477408743813
# [classification {
#   index: 0
#   score: 0.987467
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.991756618
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.572502739178946
# 5.572502739178946
# 2.786251369589473
# [classification {
#   index: 0
#   score: 0.986444175
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.988619328
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.560954605386887
# 5.560954605386887
# 2.7804773026934435
# [classification {
#   index: 0
#   score: 0.986046374
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.989139378
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.518892017781345
# 5.518892017781345
# 2.7594460088906727
# [classification {
#   index: 0
#   score: 0.988500357
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.990539
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.538920910593141
# 5.538920910593141
# 2.7694604552965707
# [classification {
#   index: 0
#   score: 0.988341868
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.992579341
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.469011187044719
# 5.469011187044719
# 2.7345055935223597
# [classification {
#   index: 0
#   score: 0.988368809
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.991500139
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.359482585661837
# 5.359482585661837
# 2.6797412928309186
# [classification {
#   index: 0
#   score: 0.988647759
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.991181493
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 5.132297388227766
# 5.132297388227766
# 2.566148694113883
# [classification {
#   index: 0
#   score: 0.990463495
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.990973711
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.790711270186279
# 4.790711270186279
# 2.3953556350931393
# [classification {
#   index: 0
#   score: 0.994241774
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.986297488
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.467199251066376
# 4.467199251066376
# 2.233599625533188
# [classification {
#   index: 0
#   score: 0.98900336
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.993504345
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 3.753349750461652
# 3.753349750461652
# 1.876674875230826
# [classification {
#   index: 0
#   score: 0.991265535
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.954918623
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 4.3096931465653086
# 4.3096931465653086
# 2.1548465732826543
# [classification {
#   index: 0
#   score: 0.983488381
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.935227394
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 6.310761382375517
# 6.310761382375517
# 3.1553806911877587
# [classification {
#   index: 0
#   score: 0.986941636
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.73027581
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 8.525844288668793
# 8.525844288668793
# 4.2629221443343965
# [classification {
#   index: 0
#   score: 0.984341085
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.912014723
#   label: "Right"
# }
# ]
# num manos previas 2
# Total dif 11.788223029923017
# 11.788223029923017
# 5.894111514961509
# [classification {
#   index: 0
#   score: 0.989271402
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.973842621
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 2.9239538129562845
# 2.9239538129562845
# [classification {
#   index: 0
#   score: 0.973222
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 3.2575228466514545
# 3.2575228466514545
# [classification {
#   index: 0
#   score: 0.982261419
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 3.4821910457933143
# 3.4821910457933143
# [classification {
#   index: 0
#   score: 0.982497036
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 3.62014991383478
# 3.62014991383478
# [classification {
#   index: 0
#   score: 0.986766
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 3.723759098234524
# 3.723759098234524
# [classification {
#   index: 0
#   score: 0.985973537
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 3.634060102131002
# 3.634060102131002
# [classification {
#   index: 0
#   score: 0.987634897
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 3.4710129767602496
# 3.4710129767602496
# [classification {
#   index: 0
#   score: 0.987410784
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 3.1172067712687976
# 3.1172067712687976
# [classification {
#   index: 0
#   score: 0.987736225
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 2.577385397473307
# 2.577385397473307
# [classification {
#   index: 0
#   score: 0.984683037
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 1.8628788059279486
# 1.8628788059279486
# [classification {
#   index: 0
#   score: 0.979397833
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 0.9324543193058901
# 0.9324543193058901
# [classification {
#   index: 0
#   score: 0.973520458
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 0.874101167685069
# 0.874101167685069
# [classification {
#   index: 0
#   score: 0.941839099
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 2.3607130596309958
# 2.3607130596309958
# [classification {
#   index: 0
#   score: 0.975975215
#   label: "Left"
# }
# ]
# num manos previas 1
# Total dif 4.734017371326388
# 4.734017371326388
# Fin del video o error al leer frame

# %%
import numpy as np

# Definir los parámetros
min_threshold = 0.075
max_threshold = 0.4
mid_size = 0.25  # Puedes ajustar este valor
k = 7.5  # Ajusta para cambiar la sensibilidad

def compute_threshold(hands_media_size):
    
    threshold = min_threshold + (max_threshold - min_threshold) / (1 + np.exp(-k * (hands_media_size - mid_size)))
    
    return threshold

# Ejemplo de uso
hands_media_size = 0.009
threshold = compute_threshold(hands_media_size)
print(f'Threshold para tamaño de manos {hands_media_size}: {threshold}')

hands_media_size = 0.05
threshold = compute_threshold(hands_media_size)
print(f'Threshold para tamaño de manos {hands_media_size}: {threshold}')

hands_media_size = 0.09
threshold = compute_threshold(hands_media_size)
print(f'Threshold para tamaño de manos {hands_media_size}: {threshold}')

hands_media_size = 0.15
threshold = compute_threshold(hands_media_size)
print(f'Threshold para tamaño de manos {hands_media_size}: {threshold}')

hands_media_size = 0.2
threshold = compute_threshold(hands_media_size)
print(f'Threshold para tamaño de manos {hands_media_size}: {threshold}')

hands_media_size = 0.3
threshold = compute_threshold(hands_media_size)
print(f'Threshold para tamaño de manos {hands_media_size}: {threshold}')
# Out:
# Threshold para tamaño de manos 0.009: 0.1208056770859064
# Threshold para tamaño de manos 0.05: 0.1342882952370658
# Threshold para tamaño de manos 0.09: 0.15022944536281926
# Threshold para tamaño de manos 0.15: 0.17926692276799727
# Threshold para tamaño de manos 0.2: 0.20738335501492733
# Threshold para tamaño de manos 0.3: 0.26761664498507265
